# %%
import numpy as np
import pandas as pd
import requests
import json

url = "https://data.cityofnewyork.us/resource/erm2-nwe9?complaint_type=Graffiti&$limit=50000"
# complaint_type=Graffiti"
r = requests.get(url)
jsonobject = r.json()
df = pd.DataFrame.from_records(jsonobject)


df.head()
# Out:
#   unique_key             created_date agency               agency_name  \
# 0   29139877  2014-10-24T13:50:06.000   DSNY  Department of Sanitation
# 1   29142818  2014-10-24T13:50:07.000   DSNY  Department of Sanitation
# 2   29143808  2014-10-24T17:32:18.000   DSNY  Department of Sanitation
# 3   29176117  2014-10-29T10:22:34.000   DSNY  Department of Sanitation
# 4   29177012  2014-10-29T18:50:08.000   DSNY  Department of Sanitation
#
#   complaint_type descriptor                       incident_address  \
# 0       Graffiti   Graffiti                             439 e20 st
# 1       Graffiti   Graffiti                             651 e20 st
# 2       Graffiti   Graffiti  3 ave 10 street transit mta wall psny
# 3       Graffiti   Graffiti                              26 26 AVE
# 4       Graffiti   Graffiti                      1139 mcdoinald av
#
#                            street_name address_type facility_type  ... city  \
# 0                               e20 st      ADDRESS           N/A  ...  NaN
# 1                               e20 st      ADDRESS           N/A  ...  NaN
# 2  ave 10 street transit mta wall psny      ADDRESS           N/A  ...  NaN
# 3                               26 AVE      ADDRESS           N/A  ...  NaN
# 4                         mcdoinald av      ADDRESS           N/A  ...  NaN
#
#    bbl x_coordinate_state_plane y_coordinate_state_plane latitude longitude  \
# 0  NaN                      NaN                      NaN      NaN       NaN
# 1  NaN                      NaN                      NaN      NaN       NaN
# 2  NaN                      NaN                      NaN      NaN       NaN
# 3  NaN                      NaN                      NaN      NaN       NaN
# 4  NaN                      NaN                      NaN      NaN       NaN
#
#   location intersection_street_1 intersection_street_2 landmark
# 0      NaN                   NaN                   NaN      NaN
# 1      NaN                   NaN                   NaN      NaN
# 2      NaN                   NaN                   NaN      NaN
# 3      NaN                   NaN                   NaN      NaN
# 4      NaN                   NaN                   NaN      NaN
#
# [5 rows x 34 columns]

# %%
df.shape
# Out:
# (50000, 34)

# %%
df['agency_name'].value_counts()
# Out:
# Department of Sanitation           46446
# New York City Police Department     3553
# New York Police Precinct               1
# Name: agency_name, dtype: int64

# %%
df['year'] = df['created_date'].str.extract('(\d\d\d\d)').astype(int)
df.head(2)
# Out:
#   unique_key             created_date agency               agency_name  \
# 0   29139877  2014-10-24T13:50:06.000   DSNY  Department of Sanitation
# 1   29142818  2014-10-24T13:50:07.000   DSNY  Department of Sanitation
#
#   complaint_type descriptor incident_address street_name address_type  \
# 0       Graffiti   Graffiti       439 e20 st      e20 st      ADDRESS
# 1       Graffiti   Graffiti       651 e20 st      e20 st      ADDRESS
#
#   facility_type  ...  bbl x_coordinate_state_plane y_coordinate_state_plane  \
# 0           N/A  ...  NaN                      NaN                      NaN
# 1           N/A  ...  NaN                      NaN                      NaN
#
#   latitude longitude location intersection_street_1 intersection_street_2  \
# 0      NaN       NaN      NaN                   NaN                   NaN
# 1      NaN       NaN      NaN                   NaN                   NaN
#
#   landmark  year
# 0      NaN  2014
# 1      NaN  2014
#
# [2 rows x 35 columns]

# %%
df.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# .plot(kind='barh')
df.borough.value_counts()
# Out:
# BROOKLYN         23180
# MANHATTAN         9864
# BRONX             8139
# QUEENS            7670
# STATEN ISLAND     1133
# Unspecified         14
# Name: borough, dtype: int64

# %%
df.borough.value_counts().sum()
# Out:
# 50000

# %%
y2020 = df[df['year']==2020]
y2020.borough.value_counts()
# Out:
# BROOKLYN         3107
# MANHATTAN        1529
# QUEENS            836
# BRONX             576
# STATEN ISLAND     466
# Unspecified         3
# Name: borough, dtype: int64

# %%
y2019 = df[df['year']==2019]
y2019.borough.value_counts()
# Out:
# BROOKLYN         9362
# MANHATTAN        4505
# BRONX            3350
# QUEENS           2634
# STATEN ISLAND     307
# Unspecified        10
# Name: borough, dtype: int64

# %%
brooklyn_2019 = df[(df['year']==2019) & (df['borough']=='BROOKLYN')]
brooklyn_2019
# Out:
#       unique_key             created_date              closed_date agency  \
# 0       42989617  2019-06-16T15:01:26.000  2019-10-04T00:00:00.000   DSNY
# 6       43009042  2019-06-18T15:01:21.000  2019-12-10T00:00:00.000   DSNY
# 11      43017355  2019-06-19T10:02:26.000  2019-12-05T00:00:00.000   DSNY
# 17      43029265  2019-06-20T08:37:20.000  2019-10-04T00:00:00.000   DSNY
# 20      43031206  2019-06-20T09:19:03.000  2019-10-18T00:00:00.000   DSNY
# ...          ...                      ...                      ...    ...
# 18009   41351096  2019-01-05T16:13:32.000                      NaN   DSNY
# 18141   41882927  2019-03-05T10:57:59.000                      NaN   DSNY
# 18149   41392013  2019-01-10T12:38:54.000                      NaN   DSNY
# 48807   43753693  2019-09-09T09:12:35.000  2020-01-02T00:00:00.000   DSNY
# 49212   43897771  2019-09-26T09:40:07.000  2020-01-03T00:00:00.000   DSNY
#
#                     agency_name complaint_type descriptor location_type  \
# 0      Department of Sanitation       Graffiti   Graffiti     Comercial
# 6      Department of Sanitation       Graffiti   Graffiti     Comercial
# 11     Department of Sanitation       Graffiti   Graffiti           NaN
# 17     Department of Sanitation       Graffiti   Graffiti     Mixed Use
# 20     Department of Sanitation       Graffiti   Graffiti     Mixed Use
# ...                         ...            ...        ...           ...
# 18009  Department of Sanitation       Graffiti   Graffiti           NaN
# 18141  Department of Sanitation       Graffiti   Graffiti           NaN
# 18149  Department of Sanitation       Graffiti   Graffiti           NaN
# 48807  Department of Sanitation       Graffiti   Graffiti     Mixed Use
# 49212  Department of Sanitation       Graffiti   Graffiti     Comercial
#
#       incident_zip         incident_address  ... park_borough  \
# 0            11206             926 BROADWAY  ...     BROOKLYN
# 6            11221            1189 BROADWAY  ...     BROOKLYN
# 11           11249       178 BEDFORD AVENUE  ...     BROOKLYN
# 17           11205    284 WILLOUGHBY AVENUE  ...     BROOKLYN
# 20           11216      369 NOSTRAND AVENUE  ...     BROOKLYN
# ...            ...                      ...  ...          ...
# 18009          NaN             254 8 Street  ...     BROOKLYN
# 18141          NaN  302kingshwy 302kingshwy  ...     BROOKLYN
# 18149          NaN           44 ESTATE ROAD  ...     BROOKLYN
# 48807          NaN   589 KNICKERBOCK AVENUE  ...     BROOKLYN
# 49212        11204           6502 18 AVENUE  ...     BROOKLYN
#
#                  latitude           longitude  \
# 0        40.6974314659344  -73.93607088254036
# 6      40.692469183277424   -73.9272624645795
# 11      40.71796949807417  -73.95759472509405
# 17      40.69253726885699  -73.95971322637483
# 20      40.68535612516557  -73.95055918728815
# ...                   ...                 ...
# 18009                 NaN                 NaN
# 18141                 NaN                 NaN
# 18149                 NaN                 NaN
# 48807                 NaN                 NaN
# 49212   40.61903867779292  -73.99028879858939
#
#                                                                                                                                            location  \
# 0       {'latitude': '40.6974314659344', 'longitude': '-73.93607088254036', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 6      {'latitude': '40.692469183277424', 'longitude': '-73.9272624645795', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 11     {'latitude': '40.71796949807417', 'longitude': '-73.95759472509405', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 17     {'latitude': '40.69253726885699', 'longitude': '-73.95971322637483', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 20     {'latitude': '40.68535612516557', 'longitude': '-73.95055918728815', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# ...                                                                                                                                             ...
# 18009                                                                                                                                           NaN
# 18141                                                                                                                                           NaN
# 18149                                                                                                                                           NaN
# 48807                                                                                                                                           NaN
# 49212  {'latitude': '40.61903867779292', 'longitude': '-73.99028879858939', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
#
#       cross_street_1 cross_street_2 intersection_street_1  \
# 0                NaN            NaN                   NaN
# 6                NaN            NaN                   NaN
# 11               NaN            NaN                   NaN
# 17               NaN            NaN                   NaN
# 20               NaN            NaN                   NaN
# ...              ...            ...                   ...
# 18009            NaN            NaN                   NaN
# 18141            NaN            NaN                   NaN
# 18149            NaN            NaN                   NaN
# 48807            NaN            NaN                   NaN
# 49212            NaN            NaN                   NaN
#
#       intersection_street_2 landmark  year
# 0                       NaN      NaN  2019
# 6                       NaN      NaN  2019
# 11                      NaN      NaN  2019
# 17                      NaN      NaN  2019
# 20                      NaN      NaN  2019
# ...                     ...      ...   ...
# 18009                   NaN      NaN  2019
# 18141                   NaN      NaN  2019
# 18149                   NaN      NaN  2019
# 48807                   NaN      NaN  2019
# 49212                   NaN      NaN  2019
#
# [2396 rows x 35 columns]

# %%
brooklyn_2021.shape
# Out:
# (19, 35)

# %%
brooklyn_2021.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'address_type', 'city',
#        'facility_type', 'status', 'due_date', 'resolution_description',
#        'resolution_action_updated_date', 'community_board', 'bbl', 'borough',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'latitude', 'longitude', 'location', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'landmark', 'year'],
#       dtype='object')

# %%
brooklyn_2021.to_csv('brooklyn_2021.csv')

# %%
brooklyn_2020 = df[(df['year']==2020) & (df['borough']=='BROOKLYN')]
brooklyn_2020
# Out:
#       unique_key             created_date closed_date agency  \
# 37      45745758  2020-03-03T06:41:49.000         NaN   DSNY
# 70      45901185  2020-03-26T13:27:54.000         NaN   DSNY
# 472     46005312  2020-04-15T10:43:57.000         NaN   DSNY
# 924     46124832  2020-05-04T14:32:21.000         NaN   DSNY
# 1083    45285101  2020-01-01T09:23:42.000         NaN   DSNY
# ...          ...                      ...         ...    ...
# 18150   45493318  2020-01-28T16:03:29.000         NaN   DSNY
# 18164   45489322  2020-01-28T13:39:23.000         NaN   DSNY
# 18166   45492559  2020-01-28T11:03:36.000         NaN   DSNY
# 18226   45489327  2020-01-28T11:13:02.000         NaN   DSNY
# 18228   45488390  2020-01-28T03:39:40.000         NaN   DSNY
#
#                     agency_name complaint_type descriptor location_type  \
# 37     Department of Sanitation       Graffiti   Graffiti     Mixed Use
# 70     Department of Sanitation       Graffiti   Graffiti           NaN
# 472    Department of Sanitation       Graffiti   Graffiti     Mixed Use
# 924    Department of Sanitation       Graffiti   Graffiti     Mixed Use
# 1083   Department of Sanitation       Graffiti   Graffiti     Mixed Use
# ...                         ...            ...        ...           ...
# 18150  Department of Sanitation       Graffiti   Graffiti     Comercial
# 18164  Department of Sanitation       Graffiti   Graffiti   Residential
# 18166  Department of Sanitation       Graffiti   Graffiti           NaN
# 18226  Department of Sanitation       Graffiti   Graffiti           NaN
# 18228  Department of Sanitation       Graffiti   Graffiti   Residential
#
#       incident_zip         incident_address  ... park_borough  \
# 37           11216     1219 ATLANTIC AVENUE  ...     BROOKLYN
# 70             NaN              2468/ 86 ST  ...     BROOKLYN
# 472          11206     100 MANHATTAN AVENUE  ...     BROOKLYN
# 924          11230    1679 EAST    3 STREET  ...     BROOKLYN
# 1083         11214  7517 NEW UTRECHT AVENUE  ...     BROOKLYN
# ...            ...                      ...  ...          ...
# 18150        11206       186 SCHOLES STREET  ...     BROOKLYN
# 18164        11221     265 EVERGREEN AVENUE  ...     BROOKLYN
# 18166          NaN           8324 84 street  ...     BROOKLYN
# 18226          NaN        8514/ Bay Parkway  ...     BROOKLYN
# 18228        11223       2292 OCEAN PARKWAY  ...     BROOKLYN
#
#                  latitude           longitude  \
# 37     40.678507890835554  -73.95049936906851
# 70                    NaN                 NaN
# 472     40.70584589650492  -73.94469381154327
# 924     40.60968391930369  -73.97100373592826
# 1083    40.61555869096264  -73.99999639811011
# ...                   ...                 ...
# 18150  40.708937785491614   -73.9417335584355
# 18164   40.69552615150693  -73.92615562886313
# 18166                 NaN                 NaN
# 18226                 NaN                 NaN
# 18228   40.59358940899362  -73.96469508807704
#
#                                                                                                                                             location  \
# 37     {'latitude': '40.678507890835554', 'longitude': '-73.95049936906851', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 70                                                                                                                                               NaN
# 472     {'latitude': '40.70584589650492', 'longitude': '-73.94469381154327', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 924     {'latitude': '40.60968391930369', 'longitude': '-73.97100373592826', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 1083    {'latitude': '40.61555869096264', 'longitude': '-73.99999639811011', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# ...                                                                                                                                              ...
# 18150   {'latitude': '40.708937785491614', 'longitude': '-73.9417335584355', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 18164   {'latitude': '40.69552615150693', 'longitude': '-73.92615562886313', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
# 18166                                                                                                                                            NaN
# 18226                                                                                                                                            NaN
# 18228   {'latitude': '40.59358940899362', 'longitude': '-73.96469508807704', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}
#
#       cross_street_1 cross_street_2 intersection_street_1  \
# 37               NaN            NaN                   NaN
# 70               NaN            NaN                   NaN
# 472              NaN            NaN                   NaN
# 924              NaN            NaN                   NaN
# 1083             NaN            NaN                   NaN
# ...              ...            ...                   ...
# 18150            NaN            NaN                   NaN
# 18164            NaN            NaN                   NaN
# 18166            NaN            NaN                   NaN
# 18226            NaN            NaN                   NaN
# 18228            NaN            NaN                   NaN
#
#       intersection_street_2 landmark  year
# 37                      NaN      NaN  2020
# 70                      NaN      NaN  2020
# 472                     NaN      NaN  2020
# 924                     NaN      NaN  2020
# 1083                    NaN      NaN  2020
# ...                     ...      ...   ...
# 18150                   NaN      NaN  2020
# 18164                   NaN      NaN  2020
# 18166                   NaN      NaN  2020
# 18226                   NaN      NaN  2020
# 18228                   NaN      NaN  2020
#
# [596 rows x 35 columns]

# %%
brooklyn_2020.to_csv('brooklyn_2020.csv')

# %%
#2019

brooklyn_2019 = df[(df['year']==2019) & (df['borough']=='BROOKLYN')]

# %%
brooklyn_2019.to_csv('brooklyn_2019.csv')

# %%
df2 = pd.read_csv('311ServiceRequests_2020.csv')
df2.head()
# Out:
# /opt/anaconda3/envs/columbia/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (17,18,20,31,32,33,34,35,36,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45462429  01/25/2020 12:49:39 AM  01/25/2020 10:13:00 AM    TLC
# 1    45462615  01/24/2020 08:45:14 PM  01/24/2020 08:45:16 PM    EDC
# 2    45466142  01/24/2020 07:26:18 AM  01/24/2020 07:26:18 AM  DOHMH
# 3    45467606  01/24/2020 10:26:00 AM  01/25/2020 12:00:00 AM    DEP
# 4    45481372  01/27/2020 07:10:37 AM  01/27/2020 07:10:40 AM    EDC
#
#                                Agency Name      Complaint Type  \
# 0            Taxi and Limousine Commission       Lost Property
# 1         Economic Development Corporation  Noise - Helicopter
# 2  Department of Health and Mental Hygiene              Rodent
# 3   Department of Environmental Protection                Lead
# 4         Economic Development Corporation  Noise - Helicopter
#
#                              Descriptor            Location Type  \
# 0                            Bag/Wallet                      NaN
# 1                                 Other            Above Address
# 2                          Rat Sighting  3+ Family Apt. Building
# 3  Lead Kit Request (Residential) (L10)                      NaN
# 4                                 Other            Above Address
#
#    Incident Zip     Incident Address  ... Vehicle Type Taxi Company Borough  \
# 0       10036.0     WEST   44 STREET  ...          NaN                  NaN
# 1       11357.0       162-12 12 ROAD  ...          NaN                  NaN
# 2       10467.0  3165 DECATUR AVENUE  ...          NaN                  NaN
# 3       11217.0    300 ASHLAND PLACE  ...          NaN                  NaN
# 4       11215.0        199 14 STREET  ...          NaN                  NaN
#
#                                           Taxi Pick Up Location  \
# 0  WEST   44 STREET BETWEEN 6 AVENUE AND BROADWAY, MANHATTAN, N
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment   Latitude  Longitude  \
# 0                    NaN        NaN        NaN
# 1                    NaN  40.790262 -73.799776
# 2                    NaN  40.872835 -73.876487
# 3                    NaN  40.686273 -73.978113
# 4                    NaN  40.666965 -73.990448
#
#                                    Location
# 0                                       NaN
# 1   (40.79026193589992, -73.79977622082558)
# 2   (40.87283464140425, -73.87648695594841)
# 3   (40.68627318421986, -73.97811334249946)
# 4  (40.666965381676256, -73.99044763544703)
#
# [5 rows x 41 columns]

# %%
graffiti = df2[df2['Complaint Type'].str.contains('Graffiti')]
graffiti
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 17         45287976  01/01/2020 04:57:47 PM                     NaN   DSNY
# 27         45293344  01/02/2020 08:41:06 AM                     NaN   DSNY
# 28         45293345  01/02/2020 08:35:15 AM                     NaN   DSNY
# 31         45293347  01/02/2020 06:06:31 PM                     NaN   DSNY
# 41         45285130  01/01/2020 09:15:11 AM                     NaN   DSNY
# ...             ...                     ...                     ...    ...
# 2590213    48537485  12/31/2020 02:03:22 PM  12/31/2020 03:12:50 PM   NYPD
# 2590282    48538027  12/31/2020 12:10:44 PM  12/31/2020 12:24:33 PM   NYPD
# 2590796    48541212  12/31/2020 09:48:31 AM  12/31/2020 10:00:29 AM   NYPD
# 2590883    48541889  12/31/2020 10:21:12 AM  12/31/2020 11:12:29 AM   NYPD
# 2591010    48542790  12/31/2020 03:58:45 PM  12/31/2020 04:25:50 PM   NYPD
#
#                              Agency Name Complaint Type  \
# 17              Department of Sanitation       Graffiti
# 27              Department of Sanitation       Graffiti
# 28              Department of Sanitation       Graffiti
# 31              Department of Sanitation       Graffiti
# 41              Department of Sanitation       Graffiti
# ...                                  ...            ...
# 2590213  New York City Police Department       Graffiti
# 2590282  New York City Police Department       Graffiti
# 2590796  New York City Police Department       Graffiti
# 2590883  New York City Police Department       Graffiti
# 2591010  New York City Police Department       Graffiti
#
#                           Descriptor               Location Type  \
# 17                          Graffiti                   Mixed Use
# 27                          Graffiti                   Comercial
# 28                          Graffiti                   Comercial
# 31                          Graffiti                   Comercial
# 41                          Graffiti                   Mixed Use
# ...                              ...                         ...
# 2590213  Police Report Not Requested             Street/Sidewalk
# 2590282      Police Report Requested  Residential Building/House
# 2590796      Police Report Requested                         NaN
# 2590883  Police Report Not Requested            Store/Commercial
# 2591010  Police Report Not Requested            Store/Commercial
#
#          Incident Zip          Incident Address  ... Vehicle Type  \
# 17            11204.0            6609 18 AVENUE  ...          NaN
# 27            10474.0      1380 SPOFFORD AVENUE  ...          NaN
# 28            10455.0         2792 THIRD AVENUE  ...          NaN
# 31            11220.0             5702 3 AVENUE  ...          NaN
# 41            11219.0   5415 NEW UTRECHT AVENUE  ...          NaN
# ...               ...                       ...  ...          ...
# 2590213       10025.0       280 RIVERSIDE DRIVE  ...          NaN
# 2590282       10005.0          82 BEAVER STREET  ...          NaN
# 2590796       11218.0            1358 38 STREET  ...          NaN
# 2590883       11222.0           232 JAVA STREET  ...          NaN
# 2591010       10036.0  600 JOE DIMAGGIO HIGHWAY  ...          NaN
#
#         Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 17                       NaN                   NaN                 NaN
# 27                       NaN                   NaN                 NaN
# 28                       NaN                   NaN                 NaN
# 31                       NaN                   NaN                 NaN
# 41                       NaN                   NaN                 NaN
# ...                      ...                   ...                 ...
# 2590213                  NaN                   NaN                 NaN
# 2590282                  NaN                   NaN                 NaN
# 2590796                  NaN                   NaN                 NaN
# 2590883                  NaN                   NaN                 NaN
# 2591010                  NaN                   NaN                 NaN
#
#         Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 17                           NaN       NaN                    NaN  40.618402
# 27                           NaN       NaN                    NaN  40.815032
# 28                           NaN       NaN                    NaN  40.815176
# 31                           NaN       NaN                    NaN  40.643647
# 41                           NaN       NaN                    NaN  40.631805
# ...                          ...       ...                    ...        ...
# 2590213                      NaN       NaN                    NaN  40.798502
# 2590282                      NaN       NaN                    NaN  40.705359
# 2590796                      NaN       NaN                    NaN  40.640431
# 2590883                      NaN       NaN                    NaN  40.731954
# 2591010                      NaN       NaN                    NaN  40.764372
#
#          Longitude                                  Location
# 17      -73.990908   (40.61840193667543, -73.99090844267874)
# 27      -73.882935   (40.81503229406327, -73.88293450110314)
# 28      -73.919256   (40.81517598505509, -73.91925629116382)
# 31      -74.018731   (40.64364733648157, -74.01873050529493)
# 41      -73.995403    (40.63180501560896, -73.9954028696561)
# ...            ...                                       ...
# 2590213 -73.972709   (40.79850212652865, -73.97270932568053)
# 2590282 -74.008602  (40.705359314572945, -74.00860207956921)
# 2590796 -73.984470   (40.64043092476985, -73.98447006803504)
# 2590883 -73.950828  (40.731954091967815, -73.95082770088665)
# 2591010 -73.998505    (40.7643718249066, -73.99850548581462)
#
# [6915 rows x 41 columns]

# %%
graffiti.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
graffiti = graffiti.drop(columns=['X Coordinate (State Plane)',
       'Y Coordinate (State Plane)', 'Open Data Channel Type',
       'Park Facility Name', 'Park Borough', 'Vehicle Type',
       'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
       'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment'])
graffiti.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
graffiti['Borough'].value_counts()
# Out:
# BROOKLYN         3282
# MANHATTAN        1646
# QUEENS            886
# BRONX             624
# STATEN ISLAND     474
# Unspecified         3
# Name: Borough, dtype: int64

# %%
brooklyn_graffiti = graffiti[graffiti['Borough']=='BROOKLYN']
pd.set_option('display.max_colwidth', 400)
brooklyn_graffiti
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 17         45287976  01/01/2020 04:57:47 PM                     NaN   DSNY
# 31         45293347  01/02/2020 06:06:31 PM                     NaN   DSNY
# 41         45285130  01/01/2020 09:15:11 AM                     NaN   DSNY
# 90         45285100  01/01/2020 09:08:20 AM                     NaN   DSNY
# 91         45285101  01/01/2020 09:23:42 AM                     NaN   DSNY
# ...             ...                     ...                     ...    ...
# 2553736    48427309  12/16/2020 09:04:29 AM                     NaN   DSNY
# 2554541    48474255  12/22/2020 03:49:56 PM  12/22/2020 04:15:43 PM   NYPD
# 2587013    48535003  12/30/2020 11:42:25 AM  12/30/2020 12:16:14 PM   NYPD
# 2590796    48541212  12/31/2020 09:48:31 AM  12/31/2020 10:00:29 AM   NYPD
# 2590883    48541889  12/31/2020 10:21:12 AM  12/31/2020 11:12:29 AM   NYPD
#
#                              Agency Name Complaint Type  \
# 17              Department of Sanitation       Graffiti
# 31              Department of Sanitation       Graffiti
# 41              Department of Sanitation       Graffiti
# 90              Department of Sanitation       Graffiti
# 91              Department of Sanitation       Graffiti
# ...                                  ...            ...
# 2553736         Department of Sanitation       Graffiti
# 2554541  New York City Police Department       Graffiti
# 2587013  New York City Police Department       Graffiti
# 2590796  New York City Police Department       Graffiti
# 2590883  New York City Police Department       Graffiti
#
#                           Descriptor     Location Type  Incident Zip  \
# 17                          Graffiti         Mixed Use       11204.0
# 31                          Graffiti         Comercial       11220.0
# 41                          Graffiti         Mixed Use       11219.0
# 90                          Graffiti         Mixed Use       11220.0
# 91                          Graffiti         Mixed Use       11214.0
# ...                              ...               ...           ...
# 2553736                     Graffiti         Comercial       11215.0
# 2554541      Police Report Requested  Store/Commercial       11236.0
# 2587013  Police Report Not Requested  Store/Commercial       11218.0
# 2590796      Police Report Requested               NaN       11218.0
# 2590883  Police Report Not Requested  Store/Commercial       11222.0
#
#                 Incident Address  ...  Status                Due Date  \
# 17                6609 18 AVENUE  ...    Open  02/29/2020 03:53:21 PM
# 31                 5702 3 AVENUE  ...    Open  02/29/2020 03:53:21 PM
# 41       5415 NEW UTRECHT AVENUE  ...    Open  02/29/2020 03:53:21 PM
# 90                 5410 5 AVENUE  ...    Open  04/13/2020 04:00:00 AM
# 91       7517 NEW UTRECHT AVENUE  ...    Open  02/29/2020 03:53:21 PM
# ...                          ...  ...     ...                     ...
# 2553736            140 18 STREET  ...    Open  01/15/2021 09:04:29 AM
# 2554541         ROCKAWAY PARKWAY  ...  Closed                     NaN
# 2587013        302 CHURCH AVENUE  ...  Closed                     NaN
# 2590796           1358 38 STREET  ...  Closed                     NaN
# 2590883          232 JAVA STREET  ...  Closed                     NaN
#
#                                                                                         Resolution Description  \
# 17                                 The graffiti on this property has been scheduled to be removed by the City.
# 31                                 The graffiti on this property has been scheduled to be removed by the City.
# 41                                 The graffiti on this property has been scheduled to be removed by the City.
# 90                                 The graffiti on this property has been scheduled to be removed by the City.
# 91                                 The graffiti on this property has been scheduled to be removed by the City.
# ...                                                                                                        ...
# 2553736                            The graffiti on this property has been scheduled to be removed by the City.
# 2554541                 The Police Department responded to the complaint and took action to fix the condition.
# 2587013                 The Police Department responded to the complaint and took action to fix the condition.
# 2590796                 The Police Department responded to the complaint and took action to fix the condition.
# 2590883  The Police Department responded to the complaint and determined that police action was not necessary.
#
#         Resolution Action Updated Date Community Board           BBL  \
# 17              01/30/2020 03:53:21 PM     11 BROOKLYN  3.055610e+09
# 31              01/30/2020 03:53:21 PM     07 BROOKLYN  3.008450e+09
# 41              01/30/2020 03:53:21 PM     12 BROOKLYN  3.056770e+09
# 90              03/14/2020 04:00:01 AM     07 BROOKLYN  3.008230e+09
# 91              01/30/2020 03:53:21 PM     11 BROOKLYN  3.062250e+09
# ...                                ...             ...           ...
# 2553736         12/16/2020 09:04:29 AM     07 BROOKLYN  3.006330e+09
# 2554541         12/22/2020 09:15:47 PM     18 BROOKLYN           NaN
# 2587013         12/30/2020 05:16:18 PM     12 BROOKLYN  3.053360e+09
# 2590796         12/31/2020 03:00:31 PM     12 BROOKLYN  3.052990e+09
# 2590883         12/31/2020 04:12:31 PM     01 BROOKLYN  3.025520e+09
#
#           Borough   Latitude  Longitude  \
# 17       BROOKLYN  40.618402 -73.990908
# 31       BROOKLYN  40.643647 -74.018731
# 41       BROOKLYN  40.631805 -73.995403
# 90       BROOKLYN  40.642748 -74.012785
# 91       BROOKLYN  40.615559 -73.999996
# ...           ...        ...        ...
# 2553736  BROOKLYN  40.664973 -73.994900
# 2554541  BROOKLYN  40.633803 -73.889694
# 2587013  BROOKLYN  40.643688 -73.977306
# 2590796  BROOKLYN  40.640431 -73.984470
# 2590883  BROOKLYN  40.731954 -73.950828
#
#                                          Location
# 17        (40.61840193667543, -73.99090844267874)
# 31        (40.64364733648157, -74.01873050529493)
# 41         (40.63180501560896, -73.9954028696561)
# 90        (40.64274786170989, -74.01278471271169)
# 91        (40.61555869096264, -73.99999639811011)
# ...                                           ...
# 2553736  (40.664972956492875, -73.99489955015797)
# 2554541   (40.63380255460564, -73.88969436313862)
# 2587013  (40.643687794347564, -73.97730573407173)
# 2590796   (40.64043092476985, -73.98447006803504)
# 2590883  (40.731954091967815, -73.95082770088665)
#
# [3282 rows x 29 columns]

# %%
brooklyn_graffiti['Resolution Description'].value_counts()
# Out:
# The graffiti on this property has been scheduled to be removed by the City.                                                                                                                                          2079
# The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.     251
# The Police Department responded to the complaint and determined that police action was not necessary.                                                                                                                 194
# The Police Department responded to the complaint and took action to fix the condition.                                                                                                                                166
# The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.                                                                               110
# The Police Department responded to the complaint and a report was prepared.                                                                                                                                            60
# This complaint does not fall under the Police Department's jurisdiction.                                                                                                                                               38
# Notifications sent by the City to the proerty owner have been returned by the Post Office as undeliverable.                                                                                                            35
# The Police Department reviewed your complaint and provided additional information below.                                                                                                                               26
# The Police Department responded and upon arrival those responsible for the condition were gone.                                                                                                                        20
# Your request can not be processed at this time because of insufficient contact information. Please create a new Service Request on NYC.gov and provide more detailed contact information.                               7
# The propery is owned by a Federal or State Agency. The City will attempt to notify the appropriate agency.                                                                                                              5
# The property owner is aware of the graffiti and ordered it not to be removed.                                                                                                                                           4
# The Police Department responded to the complaint but officers were unable to gain entry into the premises.                                                                                                              3
# The City has removed the graffiti from this property.                                                                                                                                                                   2
# The Police Department issued a summons in response to the complaint.                                                                                                                                                    1
# Name: Resolution Description, dtype: int64
